# %%
# !git clone -b opt5 https://github.com/ZesyC/Diff-Prv
# !pip install setproctitle
# Out:
# Cloning into 'Diff-Prv'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 169 (delta 87), reused 100 (delta 49), pack-reused 30 (from 1)
# Receiving objects: 100% (169/169), 76.63 MiB | 31.37 MiB/s, done. MiB/s
# Resolving deltas: 100% (89/89), done.
# ...

# %%
# !cd Diff-Prv/Datasets/baby && unzip -o image_feat.npy.zip

# !cd Diff-Prv/Prv && python Main.py \
  --data baby \
  --epoch 50 \
  --gpu 0 \
  --lr 1e-3 \
  --batch 256 \
  --tstBat 256 \
  --reg 1e-5 \
  --latdim 64 \
  --gnn_layer 1 \
  --topk 20 \
  --model_type CFM \
  --ssl_reg 1e-1 \
  --temp 0.5 \
  --tstEpoch 1 \
  --seed 421 \
  --keepRate 1 \
  --dims "[1000]" \
  --d_emb_size 10 \
  --norm False \
  --steps 5 \
  --sampling_steps 0 \
  --rebuild_k 3 \
  --cfm_residual_weight 0.15 \
  --e_loss 0.1 \
  --ris_lambda 0.5 \
  --ris_adj_lambda 0.1 \
  --trans 0 \
  --cl_method 0 \
  --gate_dim 32 \
  --gate_reg 0 \
  --modal_cond 1 \
  --behavior_cond 1 \
  --cfm_lambda 0.1 \
  --cross_fm_weight 0.01
# Out:
# Archive:  image_feat.npy.zip
#   inflating: image_feat.npy
# 2026-07-02 17:28:06.859521: Start CFM
# /content/Diff-Prv/Prv/DataHandler.py:53: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:654.)
#   return torch.sparse.FloatTensor(idxs, vals, shape).to(device)
# 2026-07-02 17:28:07.881375: Load Data
# USER 19445 ITEM 7050
# NUM OF INTERACTIONS 118551
# 2026-07-02 17:28:09.320072: Model Prepared
# 2026-07-02 17:28:09.320157: Model Initialized
# 2026-07-02 17:28:42.299626: CFM Step 76/76
# 2026-07-02 17:28:42.299646: Start to re-build UI matrix using Euler Solver
# 2026-07-02 17:28:45.319641: Rebuild image: rebuild_k = 3, generated_edges = 58335, train_overlap_ratio = 0.000000, new_edge_ratio = 1.000000, top_score_mean = 3.602143, top_score_std = 0.290363, graph_hit@20 = 0.003034
# ...
